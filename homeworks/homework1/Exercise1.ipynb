# %% [markdown]
# # Homework 1 (Dev Mody)
# ## Exercise 1

# %% [markdown]
# ##### HW1 Plotting Library Setup
#
# In all the exercises, we require you to use the libraries provided by the book (MLR) for plotting. It is much easier for marking and debugging if we all use the same setup. To get started with using the plotting library:
#
# 1. Download the zip file `MLRPlotting.zip` from Avenue.
# 2. Unzip it in the directory where you want to work.
# 3. Test that you can use the library. You may have to provide the path to where you put the library by uncommenting the first two lines in `HW1.Plotting.py`, and filling in the path on your computer.
#
# To demonstrate that the library is working for you, submit the plot of the output of the following script (`HW1.Plotting.py` on Avenue). You must, of course, fill in your actual **First Name** and **Last Name**.

# %% [markdown]
# Here is the implementation of HW1.Plotting.py in the format provided in the question

# %%
import sys
sys.path.append('homeworks/homework1/MLRPlotting')
import matplotlib.pyplot as plt
from MLRPlotting import static_plotter

# import custom plotting tools
static_plotter = static_plotter.Visualizer();

cost_1 = [1,2,7,9]
cost_2 = [9,6,3,1]
# plot the cost function history for two runs
static_plotter.plot_cost_histories([cost_1,cost_2],start=0,points=True,labels=[r'Dev',r'Mody'])
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'compare_runs_contour_plots', 'contour_plot_setup', 'draw_contour_plot', 'draw_grads', 'draw_grads_v2', 'draw_surface', 'draw_weight_path', 'make_colorspec', 'plot_cost_histories', 'plot_grad_directions', 'plot_grad_directions_v2', 'show_inputspace_path', 'single_input_plot', 'two_input_contour_horiz_plots', 'two_input_contour_plot', 'two_input_contour_vert_plots', 'two_input_original_contour_plot', 'two_input_surface_contour_plot']
